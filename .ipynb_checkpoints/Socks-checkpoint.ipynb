# %% [markdown]
# # The Sock Missing Problem:
# ## Number of Pairs as a Function of Number Stolen by the Sock Fairy

# %%
import random
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
def sampleRandoms(seed, numberMissing):
    random.seed(seed)
    left=random.sample(socks, 100-numberMissing)
    left.sort()
    pairsLeft=[i for i in left if i%2==0 and i+1 in left]
    return(len(pairsLeft))

def generateDF(numberOfRuns, numberOfSocks):
    seeds=list(range(0, numberOfRuns))
    dictionary={}
    for missing in percentMissing:
        dictionary[missing]=[sampleRandoms(seed, missing) for seed in seeds]
    df=pd.DataFrame.from_dict(dictionary, orient='index')
    return(df)

# %%
df=generateDF(1000, 100)

# %%
means=df.mean(axis=1)

# %%
fig = plt.figure()
ax = plt.axes()
plt.title("Complete Pairs As a Function of Number of Missing Socks")
plt.xlabel("Number of Missing Socks out of 100")
plt.ylabel("Number of Complete Pairs");

ax.plot(means.index, means)
